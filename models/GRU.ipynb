# %%
import os
import pandas as pd
import numpy as np
import pandas as pd
from matplotlib import pyplot
import statsmodels.api as sm
from numpy import *
from math import sqrt
from pandas import *
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Bidirectional
from tensorflow.keras.layers import BatchNormalization, Embedding, TimeDistributed, LeakyReLU
from tensorflow.keras.layers import LSTM, GRU
from tensorflow.keras.optimizers import Adam

# %%
AMZN_dataset = pd.read_csv('../datasets/AMZN.csv', parse_dates=['Date'])
MSFT_dataset = pd.read_csv('../datasets/MSFT.csv', parse_dates=['Date'])
GOOG_dataset = pd.read_csv('../datasets/GOOG.csv', parse_dates=['Date'])

# %%
AMZN_dataset.replace(0, np.nan, inplace=True)
AMZN_dataset.to_csv("../datasets/AMZN.csv", index=False)

MSFT_dataset.replace(0, np.nan, inplace=True)
MSFT_dataset.to_csv("../datasets/MSFT.csv", index=False)

GOOG_dataset.replace(0, np.nan, inplace=True)
GOOG_dataset.to_csv("../datasets/GOOG.csv", index=False)

# %%
datetime_series = pd.to_datetime(AMZN_dataset['Date'])
datetime_index = pd.DatetimeIndex(datetime_series.values)
AMZN_dataset = AMZN_dataset.set_index(datetime_index)
AMZN_dataset = AMZN_dataset.sort_values(by='Date')
AMZN_dataset = AMZN_dataset.drop(columns='Date')

datetime_series = pd.to_datetime(MSFT_dataset['Date'])
datetime_index = pd.DatetimeIndex(datetime_series.values)
MSFT_dataset = MSFT_dataset.set_index(datetime_index)
MSFT_dataset = MSFT_dataset.sort_values(by='Date')
MSFT_dataset = MSFT_dataset.drop(columns='Date')

datetime_series = pd.to_datetime(GOOG_dataset['Date'])
datetime_index = pd.DatetimeIndex(datetime_series.values)
GOOG_dataset = GOOG_dataset.set_index(datetime_index)
GOOG_dataset = GOOG_dataset.sort_values(by='Date')
GOOG_dataset = GOOG_dataset.drop(columns='Date')

# %%
AMZN_X_value = pd.DataFrame(AMZN_dataset.iloc[:, :])
AMZN_y_value = pd.DataFrame(AMZN_dataset.iloc[:, 3])

MSFT_X_value = pd.DataFrame(MSFT_dataset.iloc[:, :])
MSFT_y_value = pd.DataFrame(MSFT_dataset.iloc[:, 3])

GOOG_X_value = pd.DataFrame(GOOG_dataset.iloc[:, :])
GOOG_y_value = pd.DataFrame(GOOG_dataset.iloc[:, 3])

# %%
GOOG_X_value
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2014-01-02   27.782366   27.839401   27.603037   27.724083   27.724083
# 2014-01-03   27.770908   27.818977   27.520098   27.521841   27.521841
# 2014-01-06   27.721344   27.867046   27.557707   27.828691   27.828691
# 2014-01-07   28.019974   28.385853   27.924334   28.365179   28.365179
# 2014-01-08   28.543015   28.575891   28.226450   28.424210   28.424210
# ...                ...         ...         ...         ...         ...
# 2024-04-05  151.679993  154.839996  151.080994  153.940002  153.940002
# 2024-04-08  154.014999  156.654999  153.990005  156.139999  156.139999
# 2024-04-09  157.350006  159.889999  156.639999  158.139999  158.139999
# 2024-04-10  157.880005  158.160004  156.199997  157.660004  157.660004
# 2024-04-11  158.339996  161.119995  157.929993  160.789993  160.789993
#
#                Volume
# 2014-01-02   73129082
# 2014-01-03   66917888
# 2014-01-06   71037271
# 2014-01-07  102486711
# 2014-01-08   90036218
# ...               ...
# 2024-04-05   16289800
# 2024-04-08   16641500
# 2024-04-09   21538100
# 2024-04-10   16339200
# 2024-04-11   17832800
#
# [2586 rows x 6 columns]

# %%
GOOG_y_value
# Out:
#                  Close
# 2014-01-02   27.724083
# 2014-01-03   27.521841
# 2014-01-06   27.828691
# 2014-01-07   28.365179
# 2014-01-08   28.424210
# ...                ...
# 2024-04-05  153.940002
# 2024-04-08  156.139999
# 2024-04-09  158.139999
# 2024-04-10  157.660004
# 2024-04-11  160.789993
#
# [2586 rows x 1 columns]

# %%
# Normalized the data
X_scaler = MinMaxScaler(feature_range=(-1, 1))
y_scaler = MinMaxScaler(feature_range=(-1, 1))

# %%
X_scaler.fit(AMZN_X_value)
y_scaler.fit(AMZN_y_value)

AMZN_X_scale_dataset = X_scaler.fit_transform(AMZN_X_value)
AMZN_y_scale_dataset = y_scaler.fit_transform(AMZN_y_value)

# %%
X_scaler.fit(MSFT_X_value)
y_scaler.fit(MSFT_y_value)

MSFT_X_scale_dataset = X_scaler.fit_transform(MSFT_X_value)
MSFT_y_scale_dataset = y_scaler.fit_transform(MSFT_y_value)

# %%
X_scaler.fit(GOOG_X_value)
y_scaler.fit(GOOG_y_value)

GOOG_X_scale_dataset = X_scaler.fit_transform(GOOG_X_value)
GOOG_y_scale_dataset = y_scaler.fit_transform(GOOG_y_value)

# %%
n_steps_in = 3
n_features = AMZN_X_value.shape[1]
n_steps_out = 1

# %%
print(n_steps_in)
print(n_features)
print(n_steps_out)
# Out:
# 3
# 6
# 1

# %%
def get_X_y(X_data, y_data):
    X = list()
    y = list()
    yc = list()

    length = len(X_data)
    for i in range(0, length, 1):
        X_value = X_data[i: i + n_steps_in][:, :]
        y_value = y_data[i + n_steps_in: i + (n_steps_in + n_steps_out)][:, 0]
        yc_value = y_data[i: i + n_steps_in][:, :]
        if len(X_value) == 3 and len(y_value) == 1:
            X.append(X_value)
            y.append(y_value)
            yc.append(yc_value)

    return np.array(X), np.array(y), np.array(yc)

# %%
def predict_index(dataset, X_train, n_steps_in, n_steps_out):

    train_predict_index = dataset.iloc[n_steps_in : X_train.shape[0] + n_steps_in + n_steps_out - 1, :].index
    test_predict_index = dataset.iloc[X_train.shape[0] + n_steps_in:, :].index

    return train_predict_index, test_predict_index

# %%
def split_train_test(data):
    train_size = round(len(data) * 0.7)
    data_train = data[0:train_size]
    data_test = data[train_size:]
    return data_train, data_test

# %%
AMZN_X,  AMZN_y,  AMZN_yc = get_X_y(AMZN_X_scale_dataset, AMZN_y_scale_dataset)
AMZN_X_train,  AMZN_X_test  =  split_train_test(AMZN_X)
AMZN_y_train, AMZN_y_test  =  split_train_test(AMZN_y)
AMZN_yc_train, AMZN_yc_test, = split_train_test(AMZN_yc)
AMZN_index_train, AMZN_index_test, = predict_index(AMZN_dataset, AMZN_X_train, n_steps_in, n_steps_out)

# %%
MSFT_X,  MSFT_y,  MSFT_yc = get_X_y(MSFT_X_scale_dataset, MSFT_y_scale_dataset)
MSFT_X_train,  MSFT_X_test  =  split_train_test(MSFT_X)
MSFT_y_train, MSFT_y_test  =  split_train_test(MSFT_y)
MSFT_yc_train, MSFT_yc_test, = split_train_test(MSFT_yc)
MSFT_index_train, MSFT_index_test, = predict_index(MSFT_dataset, MSFT_X_train, n_steps_in, n_steps_out)

# %%
GOOG_X,  GOOG_y,  GOOG_yc = get_X_y(GOOG_X_scale_dataset, GOOG_y_scale_dataset)
GOOG_X_train,  GOOG_X_test  =  split_train_test(GOOG_X)
GOOG_y_train, GOOG_y_test  =  split_train_test(GOOG_y)
GOOG_yc_train, GOOG_yc_test, = split_train_test(GOOG_yc)
GOOG_index_train, GOOG_index_test, = predict_index(GOOG_dataset, GOOG_X_train, n_steps_in, n_steps_out)

# %%
LR = 0.0001
BATCH_SIZE = 128
N_EPOCH = 180

# %%
input_dim = AMZN_X_train.shape[1]
feature_size = AMZN_X_train.shape[2]
output_dim = AMZN_y_train.shape[1]

# %%
def model_GRU(input_dim, output_dim, feature_size , X_train , y_train) -> tf.keras.models.Model:
    model = Sequential()
    model.add(GRU(units= 128, return_sequences = True, input_shape=(input_dim, feature_size))) 
    model.add(GRU(units = 64, input_shape=(input_dim, feature_size), recurrent_dropout = 0.2))
    model.add(Dense(32))
    model.add(Dense(units=output_dim))
    model.compile(optimizer=Adam(lr=LR), loss='mse')
    history = model.fit(X_train, y_train, epochs=N_EPOCH, batch_size=BATCH_SIZE,
                        verbose=2, shuffle=False)

    pyplot.plot(history.history['loss'], label='train')
    pyplot.legend()
    pyplot.show()

    return model

# %%
model = model_GRU(input_dim, output_dim, feature_size , AMZN_X_train , AMZN_y_train)
print(model.summary())

yhat = model.predict(AMZN_X_test, verbose=0)
print(yhat)

rmse = sqrt(mean_squared_error(AMZN_y_test, yhat))
print(rmse)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/180
# 15/15 - 8s - loss: 0.0637 - 8s/epoch - 529ms/step
# Epoch 2/180
# 15/15 - 0s - loss: 0.0237 - 223ms/epoch - 15ms/step
# Epoch 3/180
# 15/15 - 0s - loss: 0.0317 - 233ms/epoch - 16ms/step
# Epoch 4/180
# 15/15 - 0s - loss: 0.0369 - 217ms/epoch - 14ms/step
# Epoch 5/180
# 15/15 - 0s - loss: 0.0227 - 230ms/epoch - 15ms/step
# Epoch 6/180
# 15/15 - 0s - loss: 0.0284 - 216ms/epoch - 14ms/step
# Epoch 7/180
# 15/15 - 0s - loss: 0.0132 - 220ms/epoch - 15ms/step
# Epoch 8/180
# 15/15 - 0s - loss: 0.0188 - 214ms/epoch - 14ms/step
# Epoch 9/180
# 15/15 - 0s - loss: 0.0099 - 256ms/epoch - 17ms/step
# Epoch 10/180
# 15/15 - 0s - loss: 0.0145 - 215ms/epoch - 14ms/step
# Epoch 11/180
# 15/15 - 0s - loss: 0.0067 - 232ms/epoch - 15ms/step
# Epoch 12/180
# 15/15 - 0s - loss: 0.0101 - 217ms/epoch - 14ms/step
# Epoch 13/180
# 15/15 - 0s - loss: 0.0048 - 229ms/epoch - 15ms/step
# Epoch 14/180
# 15/15 - 0s - loss: 0.0079 - 215ms/epoch - 14ms/step
# Epoch 15/180
# 15/15 - 0s - loss: 0.0040 - 217ms/epoch - 14ms/step
# Epoch 16/180
# 15/15 - 0s - loss: 0.0070 - 218ms/epoch - 15ms/step
# Epoch 17/180
# 15/15 - 0s - loss: 0.0039 - 218ms/epoch - 15ms/step
# Epoch 18/180
# 15/15 - 0s - loss: 0.0069 - 216ms/epoch - 14ms/step
# Epoch 19/180
# 15/15 - 0s - loss: 0.0043 - 229ms/epoch - 15ms/step
# Epoch 20/180
# 15/15 - 0s - loss: 0.0075 - 217ms/epoch - 14ms/step
# Epoch 21/180
# 15/15 - 0s - loss: 0.0049 - 216ms/epoch - 14ms/step
# Epoch 22/180
# 15/15 - 0s - loss: 0.0084 - 238ms/epoch - 16ms/step
# Epoch 23/180
# 15/15 - 0s - loss: 0.0058 - 227ms/epoch - 15ms/step
# Epoch 24/180
# 15/15 - 0s - loss: 0.0096 - 238ms/epoch - 16ms/step
# Epoch 25/180
# 15/15 - 0s - loss: 0.0066 - 233ms/epoch - 16ms/step
# Epoch 26/180
# 15/15 - 0s - loss: 0.0106 - 234ms/epoch - 16ms/step
# Epoch 27/180
# 15/15 - 0s - loss: 0.0072 - 246ms/epoch - 16ms/step
# Epoch 28/180
# 15/15 - 0s - loss: 0.0115 - 218ms/epoch - 15ms/step
# Epoch 29/180
# 15/15 - 0s - loss: 0.0076 - 228ms/epoch - 15ms/step
# Epoch 30/180
# 15/15 - 0s - loss: 0.0118 - 221ms/epoch - 15ms/step
# Epoch 31/180
# 15/15 - 0s - loss: 0.0075 - 217ms/epoch - 14ms/step
# Epoch 32/180
# 15/15 - 0s - loss: 0.0119 - 234ms/epoch - 16ms/step
# Epoch 33/180
# 15/15 - 0s - loss: 0.0077 - 212ms/epoch - 14ms/step
# Epoch 34/180
# 15/15 - 0s - loss: 0.0118 - 218ms/epoch - 15ms/step
# Epoch 35/180
# 15/15 - 0s - loss: 0.0085 - 217ms/epoch - 14ms/step
# Epoch 36/180
# 15/15 - 0s - loss: 0.0113 - 222ms/epoch - 15ms/step
# Epoch 37/180
# 15/15 - 0s - loss: 0.0092 - 212ms/epoch - 14ms/step
# Epoch 38/180
# 15/15 - 0s - loss: 0.0103 - 232ms/epoch - 15ms/step
# Epoch 39/180
# 15/15 - 0s - loss: 0.0079 - 216ms/epoch - 14ms/step
# Epoch 40/180
# 15/15 - 0s - loss: 0.0089 - 219ms/epoch - 15ms/step
# Epoch 41/180
# 15/15 - 0s - loss: 0.0053 - 217ms/epoch - 14ms/step
# Epoch 42/180
# 15/15 - 0s - loss: 0.0073 - 215ms/epoch - 14ms/step
# Epoch 43/180
# 15/15 - 0s - loss: 0.0044 - 217ms/epoch - 14ms/step
# Epoch 44/180
# 15/15 - 0s - loss: 0.0060 - 218ms/epoch - 15ms/step
# Epoch 45/180
# 15/15 - 0s - loss: 0.0039 - 217ms/epoch - 14ms/step
# Epoch 46/180
# 15/15 - 0s - loss: 0.0054 - 217ms/epoch - 14ms/step
# Epoch 47/180
# 15/15 - 0s - loss: 0.0034 - 268ms/epoch - 18ms/step
# Epoch 48/180
# 15/15 - 0s - loss: 0.0049 - 213ms/epoch - 14ms/step
# Epoch 49/180
# 15/15 - 0s - loss: 0.0030 - 217ms/epoch - 14ms/step
# Epoch 50/180
# 15/15 - 0s - loss: 0.0044 - 232ms/epoch - 15ms/step
# Epoch 51/180
# 15/15 - 0s - loss: 0.0027 - 217ms/epoch - 14ms/step
# Epoch 52/180
# 15/15 - 0s - loss: 0.0040 - 217ms/epoch - 14ms/step
# Epoch 53/180
# 15/15 - 0s - loss: 0.0025 - 234ms/epoch - 16ms/step
# Epoch 54/180
# 15/15 - 0s - loss: 0.0038 - 217ms/epoch - 14ms/step
# Epoch 55/180
# 15/15 - 0s - loss: 0.0024 - 217ms/epoch - 14ms/step
# Epoch 56/180
# 15/15 - 0s - loss: 0.0037 - 233ms/epoch - 16ms/step
# Epoch 57/180
# 15/15 - 0s - loss: 0.0024 - 217ms/epoch - 14ms/step
# Epoch 58/180
# 15/15 - 0s - loss: 0.0037 - 226ms/epoch - 15ms/step
# Epoch 59/180
# 15/15 - 0s - loss: 0.0025 - 213ms/epoch - 14ms/step
# Epoch 60/180
# 15/15 - 0s - loss: 0.0038 - 215ms/epoch - 14ms/step
# Epoch 61/180
# 15/15 - 0s - loss: 0.0026 - 217ms/epoch - 14ms/step
# Epoch 62/180
# 15/15 - 0s - loss: 0.0039 - 216ms/epoch - 14ms/step
# Epoch 63/180
# 15/15 - 0s - loss: 0.0027 - 218ms/epoch - 15ms/step
# Epoch 64/180
# 15/15 - 0s - loss: 0.0041 - 215ms/epoch - 14ms/step
# Epoch 65/180
# 15/15 - 0s - loss: 0.0028 - 218ms/epoch - 15ms/step
# Epoch 66/180
# 15/15 - 0s - loss: 0.0044 - 217ms/epoch - 14ms/step
# Epoch 67/180
# 15/15 - 0s - loss: 0.0030 - 257ms/epoch - 17ms/step
# Epoch 68/180
# 15/15 - 0s - loss: 0.0047 - 215ms/epoch - 14ms/step
# Epoch 69/180
# 15/15 - 0s - loss: 0.0032 - 230ms/epoch - 15ms/step
# Epoch 70/180
# 15/15 - 0s - loss: 0.0050 - 232ms/epoch - 15ms/step
# Epoch 71/180
# 15/15 - 0s - loss: 0.0034 - 213ms/epoch - 14ms/step
# Epoch 72/180
# 15/15 - 0s - loss: 0.0053 - 221ms/epoch - 15ms/step
# Epoch 73/180
# 15/15 - 0s - loss: 0.0036 - 217ms/epoch - 14ms/step
# Epoch 74/180
# 15/15 - 0s - loss: 0.0056 - 217ms/epoch - 14ms/step
# Epoch 75/180
# 15/15 - 0s - loss: 0.0037 - 212ms/epoch - 14ms/step
# Epoch 76/180
# 15/15 - 0s - loss: 0.0058 - 216ms/epoch - 14ms/step
# Epoch 77/180
# 15/15 - 0s - loss: 0.0038 - 219ms/epoch - 15ms/step
# Epoch 78/180
# 15/15 - 0s - loss: 0.0059 - 228ms/epoch - 15ms/step
# Epoch 79/180
# 15/15 - 0s - loss: 0.0038 - 234ms/epoch - 16ms/step
# Epoch 80/180
# 15/15 - 0s - loss: 0.0060 - 216ms/epoch - 14ms/step
# Epoch 81/180
# 15/15 - 0s - loss: 0.0039 - 226ms/epoch - 15ms/step
# Epoch 82/180
# 15/15 - 0s - loss: 0.0061 - 217ms/epoch - 14ms/step
# Epoch 83/180
# 15/15 - 0s - loss: 0.0038 - 217ms/epoch - 14ms/step
# Epoch 84/180
# 15/15 - 0s - loss: 0.0065 - 220ms/epoch - 15ms/step
# Epoch 85/180
# 15/15 - 0s - loss: 0.0041 - 217ms/epoch - 14ms/step
# Epoch 86/180
# 15/15 - 0s - loss: 0.0061 - 217ms/epoch - 14ms/step
# Epoch 87/180
# 15/15 - 0s - loss: 0.0039 - 227ms/epoch - 15ms/step
# Epoch 88/180
# 15/15 - 0s - loss: 0.0053 - 257ms/epoch - 17ms/step
# Epoch 89/180
# 15/15 - 0s - loss: 0.0036 - 230ms/epoch - 15ms/step
# Epoch 90/180
# 15/15 - 0s - loss: 0.0052 - 217ms/epoch - 14ms/step
# Epoch 91/180
# 15/15 - 0s - loss: 0.0030 - 216ms/epoch - 14ms/step
# Epoch 92/180
# 15/15 - 0s - loss: 0.0045 - 234ms/epoch - 16ms/step
# Epoch 93/180
# 15/15 - 0s - loss: 0.0026 - 233ms/epoch - 16ms/step
# Epoch 94/180
# 15/15 - 0s - loss: 0.0040 - 239ms/epoch - 16ms/step
# Epoch 95/180
# 15/15 - 0s - loss: 0.0026 - 217ms/epoch - 14ms/step
# Epoch 96/180
# 15/15 - 0s - loss: 0.0038 - 233ms/epoch - 16ms/step
# Epoch 97/180
# 15/15 - 0s - loss: 0.0025 - 233ms/epoch - 16ms/step
# Epoch 98/180
# 15/15 - 0s - loss: 0.0037 - 222ms/epoch - 15ms/step
# Epoch 99/180
# 15/15 - 0s - loss: 0.0025 - 222ms/epoch - 15ms/step
# Epoch 100/180
# 15/15 - 0s - loss: 0.0037 - 215ms/epoch - 14ms/step
# Epoch 101/180
# 15/15 - 0s - loss: 0.0025 - 226ms/epoch - 15ms/step
# Epoch 102/180
# 15/15 - 0s - loss: 0.0038 - 224ms/epoch - 15ms/step
# Epoch 103/180
# 15/15 - 0s - loss: 0.0024 - 217ms/epoch - 14ms/step
# Epoch 104/180
# 15/15 - 0s - loss: 0.0037 - 217ms/epoch - 14ms/step
# Epoch 105/180
# 15/15 - 0s - loss: 0.0025 - 217ms/epoch - 14ms/step
# Epoch 106/180
# 15/15 - 0s - loss: 0.0038 - 233ms/epoch - 16ms/step
# Epoch 107/180
# 15/15 - 0s - loss: 0.0025 - 217ms/epoch - 14ms/step
# Epoch 108/180
# 15/15 - 0s - loss: 0.0038 - 210ms/epoch - 14ms/step
# Epoch 109/180
# 15/15 - 0s - loss: 0.0025 - 250ms/epoch - 17ms/step
# Epoch 110/180
# 15/15 - 0s - loss: 0.0039 - 228ms/epoch - 15ms/step
# Epoch 111/180
# 15/15 - 0s - loss: 0.0026 - 217ms/epoch - 14ms/step
# Epoch 112/180
# 15/15 - 0s - loss: 0.0040 - 218ms/epoch - 15ms/step
# Epoch 113/180
# 15/15 - 0s - loss: 0.0026 - 216ms/epoch - 14ms/step
# Epoch 114/180
# 15/15 - 0s - loss: 0.0041 - 206ms/epoch - 14ms/step
# Epoch 115/180
# 15/15 - 0s - loss: 0.0027 - 217ms/epoch - 14ms/step
# Epoch 116/180
# 15/15 - 0s - loss: 0.0042 - 219ms/epoch - 15ms/step
# Epoch 117/180
# 15/15 - 0s - loss: 0.0027 - 229ms/epoch - 15ms/step
# Epoch 118/180
# 15/15 - 0s - loss: 0.0044 - 217ms/epoch - 14ms/step
# Epoch 119/180
# 15/15 - 0s - loss: 0.0028 - 217ms/epoch - 14ms/step
# Epoch 120/180
# 15/15 - 0s - loss: 0.0047 - 220ms/epoch - 15ms/step
# Epoch 121/180
# 15/15 - 0s - loss: 0.0029 - 225ms/epoch - 15ms/step
# Epoch 122/180
# 15/15 - 0s - loss: 0.0046 - 217ms/epoch - 14ms/step
# Epoch 123/180
# 15/15 - 0s - loss: 0.0030 - 216ms/epoch - 14ms/step
# Epoch 124/180
# 15/15 - 0s - loss: 0.0043 - 216ms/epoch - 14ms/step
# Epoch 125/180
# 15/15 - 0s - loss: 0.0030 - 221ms/epoch - 15ms/step
# Epoch 126/180
# 15/15 - 0s - loss: 0.0042 - 218ms/epoch - 15ms/step
# Epoch 127/180
# 15/15 - 0s - loss: 0.0025 - 217ms/epoch - 14ms/step
# Epoch 128/180
# 15/15 - 0s - loss: 0.0041 - 233ms/epoch - 16ms/step
# Epoch 129/180
# 15/15 - 0s - loss: 0.0023 - 250ms/epoch - 17ms/step
# Epoch 130/180
# 15/15 - 0s - loss: 0.0035 - 217ms/epoch - 14ms/step
# Epoch 131/180
# 15/15 - 0s - loss: 0.0021 - 217ms/epoch - 14ms/step
# Epoch 132/180
# 15/15 - 0s - loss: 0.0032 - 217ms/epoch - 14ms/step
# Epoch 133/180
# 15/15 - 0s - loss: 0.0021 - 218ms/epoch - 15ms/step
# Epoch 134/180
# 15/15 - 0s - loss: 0.0031 - 216ms/epoch - 14ms/step
# Epoch 135/180
# 15/15 - 0s - loss: 0.0021 - 228ms/epoch - 15ms/step
# Epoch 136/180
# 15/15 - 0s - loss: 0.0033 - 217ms/epoch - 14ms/step
# Epoch 137/180
# 15/15 - 0s - loss: 0.0021 - 216ms/epoch - 14ms/step
# Epoch 138/180
# 15/15 - 0s - loss: 0.0034 - 209ms/epoch - 14ms/step
# Epoch 139/180
# 15/15 - 0s - loss: 0.0022 - 217ms/epoch - 14ms/step
# Epoch 140/180
# 15/15 - 0s - loss: 0.0035 - 218ms/epoch - 15ms/step
# Epoch 141/180
# 15/15 - 0s - loss: 0.0023 - 217ms/epoch - 14ms/step
# Epoch 142/180
# 15/15 - 0s - loss: 0.0036 - 222ms/epoch - 15ms/step
# Epoch 143/180
# 15/15 - 0s - loss: 0.0024 - 225ms/epoch - 15ms/step
# Epoch 144/180
# 15/15 - 0s - loss: 0.0038 - 233ms/epoch - 16ms/step
# Epoch 145/180
# 15/15 - 0s - loss: 0.0025 - 217ms/epoch - 14ms/step
# Epoch 146/180
# 15/15 - 0s - loss: 0.0040 - 216ms/epoch - 14ms/step
# Epoch 147/180
# 15/15 - 0s - loss: 0.0025 - 217ms/epoch - 14ms/step
# Epoch 148/180
# 15/15 - 0s - loss: 0.0043 - 217ms/epoch - 14ms/step
# Epoch 149/180
# 15/15 - 0s - loss: 0.0026 - 250ms/epoch - 17ms/step
# Epoch 150/180
# 15/15 - 0s - loss: 0.0042 - 211ms/epoch - 14ms/step
# Epoch 151/180
# 15/15 - 0s - loss: 0.0027 - 217ms/epoch - 14ms/step
# Epoch 152/180
# 15/15 - 0s - loss: 0.0039 - 220ms/epoch - 15ms/step
# Epoch 153/180
# 15/15 - 0s - loss: 0.0025 - 217ms/epoch - 14ms/step
# Epoch 154/180
# 15/15 - 0s - loss: 0.0038 - 221ms/epoch - 15ms/step
# Epoch 155/180
# 15/15 - 0s - loss: 0.0023 - 227ms/epoch - 15ms/step
# Epoch 156/180
# 15/15 - 0s - loss: 0.0035 - 217ms/epoch - 14ms/step
# Epoch 157/180
# 15/15 - 0s - loss: 0.0021 - 217ms/epoch - 14ms/step
# Epoch 158/180
# 15/15 - 0s - loss: 0.0033 - 217ms/epoch - 14ms/step
# Epoch 159/180
# 15/15 - 0s - loss: 0.0020 - 224ms/epoch - 15ms/step
# Epoch 160/180
# 15/15 - 0s - loss: 0.0033 - 217ms/epoch - 14ms/step
# Epoch 161/180
# 15/15 - 0s - loss: 0.0020 - 217ms/epoch - 14ms/step
# Epoch 162/180
# 15/15 - 0s - loss: 0.0033 - 216ms/epoch - 14ms/step
# Epoch 163/180
# 15/15 - 0s - loss: 0.0020 - 217ms/epoch - 14ms/step
# Epoch 164/180
# 15/15 - 0s - loss: 0.0032 - 217ms/epoch - 14ms/step
# Epoch 165/180
# 15/15 - 0s - loss: 0.0020 - 217ms/epoch - 14ms/step
# Epoch 166/180
# 15/15 - 0s - loss: 0.0033 - 217ms/epoch - 14ms/step
# Epoch 167/180
# 15/15 - 0s - loss: 0.0020 - 217ms/epoch - 14ms/step
# Epoch 168/180
# 15/15 - 0s - loss: 0.0033 - 229ms/epoch - 15ms/step
# Epoch 169/180
# 15/15 - 0s - loss: 0.0020 - 250ms/epoch - 17ms/step
# Epoch 170/180
# 15/15 - 0s - loss: 0.0034 - 217ms/epoch - 14ms/step
# Epoch 171/180
# 15/15 - 0s - loss: 0.0021 - 216ms/epoch - 14ms/step
# Epoch 172/180
# 15/15 - 0s - loss: 0.0034 - 223ms/epoch - 15ms/step
# Epoch 173/180
# 15/15 - 0s - loss: 0.0021 - 217ms/epoch - 14ms/step
# Epoch 174/180
# 15/15 - 0s - loss: 0.0034 - 217ms/epoch - 14ms/step
# Epoch 175/180
# 15/15 - 0s - loss: 0.0021 - 217ms/epoch - 14ms/step
# Epoch 176/180
# 15/15 - 0s - loss: 0.0034 - 217ms/epoch - 14ms/step
# Epoch 177/180
# 15/15 - 0s - loss: 0.0021 - 229ms/epoch - 15ms/step
# Epoch 178/180
# 15/15 - 0s - loss: 0.0035 - 219ms/epoch - 15ms/step
# Epoch 179/180
# 15/15 - 0s - loss: 0.0021 - 218ms/epoch - 15ms/step
# Epoch 180/180
# 15/15 - 0s - loss: 0.0034 - 216ms/epoch - 14ms/step
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_4 (GRU)                 (None,
#  [ 7.32111037e-01]
#  [ 7.71452367e-01]
#  [ 7.93987095e-01]
#  [ 7.94703007e-01]
#  [ 7.95515478e-01]
#  [ 8.07964385e-01]
#  [ 8.16265047e-01]
#  [ 8.04616988e-01]
#  [ 7.98982620e-01]
#  [ 7.93453395e-01]
#  [ 7.92871296e-01]
#  [ 7.83904433e-01]
#  [ 7.82772243e-01]
#  [ 8.01698923e-01]
#  [ 8.20963800e-01]
#  [ 8.34394813e-01]
#  [ 8.33649457e-01]
#  [ 8.28994930e-01]
#  [ 8.31871092e-01]
#  [ 8.44743073e-01]
#  [ 8.56436133e-01]
#  [ 8.50733697e-01]
#  [ 8.41949761e-01]
#  [ 8.41559112e-01]
#  [ 8.44057918e-01]
#  [ 8.35583210e-01]
#  [ 8.33906949e-01]
#  [ 8.39240551e-01]
#  [ 8.52796972e-01]
#  [ 8.48165214e-01]
#  [ 8.44193757e-01]
#  [ 8.41276109e-01]
#  [ 8.47669721e-01]
#  [ 8.58751833e-01]
#  [ 8.65162671e-01]
#  [ 8.69612753e-01]
#  [ 8.69127333e-01]
#  [ 8.71508062e-01]
#  [ 8.75159681e-01]
#  [ 8.80953312e-01]
#  [ 8.81073058e-01]
#  [ 8.84544313e-01]
#  [ 8.85921896e-01]
#  [ 8.97426069e-01]
#  [ 9.09213126e-01]
#  [ 9.17276978e-01]
#  [ 9.17137504e-01]
#  [ 9.24527228e-01]]
# 0.06286195236176258

# %%
def plot_traindataset_result(X_train, y_train,train_index):
    train_yhat = model.predict(X_train, verbose=0)

    rescaled_real_y = y_scaler.inverse_transform(y_train)
    rescaled_predicted_y = y_scaler.inverse_transform(train_yhat)

    predict_result = pd.DataFrame()
    for i in range(rescaled_predicted_y.shape[0]):
        y_predict = pd.DataFrame(rescaled_predicted_y[i], columns=["predicted_price"],
                                 index= train_index[i:i + output_dim])
        predict_result = pd.concat([predict_result, y_predict], axis=1, sort=False)

    real_price = pd.DataFrame()
    for i in range(rescaled_real_y.shape[0]):
        y_train = pd.DataFrame(rescaled_real_y[i], columns=["real_price"],
                               index=train_index[i:i + output_dim])
        real_price = pd.concat([real_price, y_train], axis=1, sort=False)

    predict_result['predicted_mean'] = predict_result.mean(axis=1)
    real_price['real_mean'] = real_price.mean(axis=1)

    # Plot the predicted result
    plt.figure(figsize=(16, 8))
    plt.plot(real_price["real_mean"])
    plt.plot(predict_result["predicted_mean"], color='r')
    plt.xlabel("Date")
    plt.ylabel("Stock price")
    plt.legend(("Real price", "Predicted price"), loc="upper left", fontsize=16)
    plt.title("The result of Train", fontsize=20)
    plt.show()

    # Calculate RMSE
    predicted = predict_result["predicted_mean"]
    real = real_price["real_mean"]
    For_MSE = pd.concat([predicted, real], axis=1)
    RMSE = np.sqrt(mean_squared_error(predicted, real))
    #print('-- Train RMSE -- ', RMSE)

    return RMSE

# %%
train_RMSE = plot_traindataset_result(AMZN_X_train, AMZN_y_train , AMZN_index_train)
print("GRU Training set RMSE : ", train_RMSE)
# Out:
# C:\Users\cs20b\AppData\Local\Temp\ipykernel_20028\2882637674.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   predict_result['predicted_mean'] = predict_result.mean(axis=1)
# C:\Users\cs20b\AppData\Local\Temp\ipykernel_20028\2882637674.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   real_price['real_mean'] = real_price.mean(axis=1)
# GRU Training set RMSE :  3.515383244351859

# %%
def plot_testdataset_result(X_test, y_test , test_index):

    test_yhat = model.predict(X_test, verbose=0)

    rescaled_real_y = y_scaler.inverse_transform(y_test)
    rescaled_predicted_y = y_scaler.inverse_transform(test_yhat)

    predict_result = pd.DataFrame()
    for i in range(rescaled_predicted_y.shape[0]):
        y_predict = pd.DataFrame(rescaled_predicted_y[i], columns=["predicted_price"],
                                 index=test_index[i:i + output_dim])
        predict_result = pd.concat([predict_result, y_predict], axis=1, sort=False)

    real_price = pd.DataFrame()
    for i in range(rescaled_real_y.shape[0]):
        y_train = pd.DataFrame(rescaled_real_y[i], columns=["real_price"],
                               index=test_index[i:i + output_dim])
        real_price = pd.concat([real_price, y_train], axis=1, sort=False)

    predict_result['predicted_mean'] = predict_result.mean(axis=1)
    real_price['real_mean'] = real_price.mean(axis=1)

    Input_Before = '2024-02-01'
    predict_result = predict_result.loc[predict_result.index < Input_Before]
    real_price = real_price.loc[real_price.index < Input_Before]

    print(predict_result.tail(10))

    # Plot the predicted result
    plt.figure(figsize=(16, 8))
    plt.plot(real_price["real_mean"])
    plt.plot(predict_result["predicted_mean"], color='r')
    plt.xlabel("Date")
    plt.ylabel("Stock price")
    plt.legend(("Real price", "Predicted price"), loc="upper left", fontsize=16)
    plt.title("The result of Testing", fontsize=20)
    plt.show()

    # Calculate RMSE
    predicted = predict_result["predicted_mean"]
    real = real_price["real_mean"]
    RMSE = np.sqrt(mean_squared_error(predicted, real))
    #print('-- Test RMSE -- ', RMSE)

    return RMSE

# %%
test_RMSE = plot_traindataset_result(AMZN_X_test, AMZN_y_test, AMZN_index_test)
print("GRU Test set RMSE : ", test_RMSE)
# Out:
# C:\Users\cs20b\AppData\Local\Temp\ipykernel_20028\2882637674.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   predict_result['predicted_mean'] = predict_result.mean(axis=1)
# C:\Users\cs20b\AppData\Local\Temp\ipykernel_20028\2882637674.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   real_price['real_mean'] = real_price.mean(axis=1)
# GRU Test set RMSE :  4.2818390616680855

# %%
model = model_GRU(input_dim, output_dim, feature_size , MSFT_X_train , MSFT_y_train)
print(model.summary())

yhat = model.predict(MSFT_X_test, verbose=0)
print(yhat)

rmse = sqrt(mean_squared_error(MSFT_y_test, yhat))
print(rmse)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/180
# 14/14 - 4s - loss: 0.1578 - 4s/epoch - 256ms/step
# Epoch 2/180
# 14/14 - 0s - loss: 0.0167 - 118ms/epoch - 8ms/step
# Epoch 3/180
# 14/14 - 0s - loss: 0.0031 - 116ms/epoch - 8ms/step
# Epoch 4/180
# 14/14 - 0s - loss: 0.0027 - 115ms/epoch - 8ms/step
# Epoch 5/180
# 14/14 - 0s - loss: 0.0015 - 117ms/epoch - 8ms/step
# Epoch 6/180
# 14/14 - 0s - loss: 9.7501e-04 - 100ms/epoch - 7ms/step
# Epoch 7/180
# 14/14 - 0s - loss: 3.3503e-04 - 117ms/epoch - 8ms/step
# Epoch 8/180
# 14/14 - 0s - loss: 2.6658e-04 - 121ms/epoch - 9ms/step
# Epoch 9/180
# 14/14 - 0s - loss: 2.8969e-04 - 111ms/epoch - 8ms/step
# Epoch 10/180
# 14/14 - 0s - loss: 2.6161e-04 - 104ms/epoch - 7ms/step
# Epoch 11/180
# 14/14 - 0s - loss: 2.5161e-04 - 123ms/epoch - 9ms/step
# Epoch 12/180
# 14/14 - 0s - loss: 2.5194e-04 - 123ms/epoch - 9ms/step
# Epoch 13/180
# 14/14 - 0s - loss: 2.5106e-04 - 125ms/epoch - 9ms/step
# Epoch 14/180
# 14/14 - 0s - loss: 2.4742e-04 - 118ms/epoch - 8ms/step
# Epoch 15/180
# 14/14 - 0s - loss: 2.4020e-04 - 125ms/epoch - 9ms/step
# Epoch 16/180
# 14/14 - 0s - loss: 2.4360e-04 - 117ms/epoch - 8ms/step
# Epoch 17/180
# 14/14 - 0s - loss: 2.4204e-04 - 133ms/epoch - 10ms/step
# Epoch 18/180
# 14/14 - 0s - loss: 2.3853e-04 - 149ms/epoch - 11ms/step
# Epoch 19/180
# 14/14 - 0s - loss: 2.3969e-04 - 117ms/epoch - 8ms/step
# Epoch 20/180
# 14/14 - 0s - loss: 2.3761e-04 - 117ms/epoch - 8ms/step
# Epoch 21/180
# 14/14 - 0s - loss: 2.4356e-04 - 118ms/epoch - 8ms/step
# Epoch 22/180
# 14/14 - 0s - loss: 2.3310e-04 - 114ms/epoch - 8ms/step
# Epoch 23/180
# 14/14 - 0s - loss: 2.3847e-04 - 118ms/epoch - 8ms/step
# Epoch 24/180
# 14/14 - 0s - loss: 2.4076e-04 - 113ms/epoch - 8ms/step
# Epoch 25/180
# 14/14 - 0s - loss: 2.4055e-04 - 121ms/epoch - 9ms/step
# Epoch 26/180
# 14/14 - 0s - loss: 2.4221e-04 - 99ms/epoch - 7ms/step
# Epoch 27/180
# 14/14 - 0s - loss: 2.4689e-04 - 116ms/epoch - 8ms/step
# Epoch 28/180
# 14/14 - 0s - loss: 2.5226e-04 - 115ms/epoch - 8ms/step
# Epoch 29/180
# 14/14 - 0s - loss: 2.5515e-04 - 100ms/epoch - 7ms/step
# Epoch 30/180
# 14/14 - 0s - loss: 2.6578e-04 - 117ms/epoch - 8ms/step
# Epoch 31/180
# 14/14 - 0s - loss: 2.7688e-04 - 100ms/epoch - 7ms/step
# Epoch 32/180
# 14/14 - 0s - loss: 2.8932e-04 - 117ms/epoch - 8ms/step
# Epoch 33/180
# 14/14 - 0s - loss: 3.0526e-04 - 101ms/epoch - 7ms/step
# Epoch 34/180
# 14/14 - 0s - loss: 3.0858e-04 - 117ms/epoch - 8ms/step
# Epoch 35/180
# 14/14 - 0s - loss: 3.2866e-04 - 115ms/epoch - 8ms/step
# Epoch 36/180
# 14/14 - 0s - loss: 3.4035e-04 - 106ms/epoch - 8ms/step
# Epoch 37/180
# 14/14 - 0s - loss: 3.5029e-04 - 117ms/epoch - 8ms/step
# Epoch 38/180
# 14/14 - 0s - loss: 3.7524e-04 - 100ms/epoch - 7ms/step
# Epoch 39/180
# 14/14 - 0s - loss: 4.1449e-04 - 115ms/epoch - 8ms/step
# Epoch 40/180
# 14/14 - 0s - loss: 4.4630e-04 - 118ms/epoch - 8ms/step
# Epoch 41/180
# 14/14 - 0s - loss: 4.8996e-04 - 114ms/epoch - 8ms/step
# Epoch 42/180
# 14/14 - 0s - loss: 5.0530e-04 - 103ms/epoch - 7ms/step
# Epoch 43/180
# 14/14 - 0s - loss: 5.7206e-04 - 115ms/epoch - 8ms/step
# Epoch 44/180
# 14/14 - 0s - loss: 6.1965e-04 - 112ms/epoch - 8ms/step
# Epoch 45/180
# 14/14 - 0s - loss: 7.0325e-04 - 114ms/epoch - 8ms/step
# Epoch 46/180
# 14/14 - 0s - loss: 7.9305e-04 - 101ms/epoch - 7ms/step
# Epoch 47/180
# 14/14 - 0s - loss: 9.1424e-04 - 117ms/epoch - 8ms/step
# Epoch 48/180
# 14/14 - 0s - loss: 0.0010 - 100ms/epoch - 7ms/step
# Epoch 49/180
# 14/14 - 0s - loss: 0.0013 - 108ms/epoch - 8ms/step
# Epoch 50/180
# 14/14 - 0s - loss: 0.0015 - 100ms/epoch - 7ms/step
# Epoch 51/180
# 14/14 - 0s - loss: 0.0018 - 111ms/epoch - 8ms/step
# Epoch 52/180
# 14/14 - 0s - loss: 0.0023 - 107ms/epoch - 8ms/step
# Epoch 53/180
# 14/14 - 0s - loss: 0.0028 - 100ms/epoch - 7ms/step
# Epoch 54/180
# 14/14 - 0s - loss: 0.0033 - 135ms/epoch - 10ms/step
# Epoch 55/180
# 14/14 - 0s - loss: 0.0037 - 109ms/epoch - 8ms/step
# Epoch 56/180
# 14/14 - 0s - loss: 0.0037 - 121ms/epoch - 9ms/step
# Epoch 57/180
# 14/14 - 0s - loss: 0.0032 - 112ms/epoch - 8ms/step
# Epoch 58/180
# 14/14 - 0s - loss: 0.0022 - 102ms/epoch - 7ms/step
# Epoch 59/180
# 14/14 - 0s - loss: 0.0011 - 115ms/epoch - 8ms/step
# Epoch 60/180
# 14/14 - 0s - loss: 4.9399e-04 - 115ms/epoch - 8ms/step
# Epoch 61/180
# 14/14 - 0s - loss: 2.9239e-04 - 100ms/epoch - 7ms/step
# Epoch 62/180
# 14/14 - 0s - loss: 3.7486e-04 - 124ms/epoch - 9ms/step
# Epoch 63/180
# 14/14 - 0s - loss: 6.1963e-04 - 110ms/epoch - 8ms/step
# Epoch 64/180
# 14/14 - 0s - loss: 8.2571e-04 - 105ms/epoch - 7ms/step
# Epoch 65/180
# 14/14 - 0s - loss: 0.0010 - 101ms/epoch - 7ms/step
# Epoch 66/180
# 14/14 - 0s - loss: 0.0010 - 99ms/epoch - 7ms/step
# Epoch 67/180
# 14/14 - 0s - loss: 0.0010 - 117ms/epoch - 8ms/step
# Epoch 68/180
# 14/14 - 0s - loss: 8.7072e-04 - 100ms/epoch - 7ms/step
# Epoch 69/180
# 14/14 - 0s - loss: 6.6758e-04 - 99ms/epoch - 7ms/step
# Epoch 70/180
# 14/14 - 0s - loss: 4.8602e-04 - 119ms/epoch - 8ms/step
# Epoch 71/180
# 14/14 - 0s - loss: 3.1500e-04 - 99ms/epoch - 7ms/step
# Epoch 72/180
# 14/14 - 0s - loss: 2.1963e-04 - 101ms/epoch - 7ms/step
# Epoch 73/180
# 14/14 - 0s - loss: 1.7923e-04 - 114ms/epoch - 8ms/step
# Epoch 74/180
# 14/14 - 0s - loss: 2.0810e-04 - 101ms/epoch - 7ms/step
# Epoch 75/180
# 14/14 - 0s - loss: 2.9072e-04 - 116ms/epoch - 8ms/step
# Epoch 76/180
# 14/14 - 0s - loss: 4.6794e-04 - 115ms/epoch - 8ms/step
# Epoch 77/180
# 14/14 - 0s - loss: 6.5794e-04 - 100ms/epoch - 7ms/step
# Epoch 78/180
# 14/14 - 0s - loss: 8.9477e-04 - 117ms/epoch - 8ms/step
# Epoch 79/180
# 14/14 - 0s - loss: 0.0012 - 102ms/epoch - 7ms/step
# Epoch 80/180
# 14/14 - 0s - loss: 0.0014 - 120ms/epoch - 9ms/step
# Epoch 81/180
# 14/14 - 0s - loss: 0.0016 - 113ms/epoch - 8ms/step
# Epoch 82/180
# 14/14 - 0s - loss: 0.0017 - 103ms/epoch - 7ms/step
# Epoch 83/180
# 14/14 - 0s - loss: 0.0017 - 116ms/epoch - 8ms/step
# Epoch 84/180
# 14/14 - 0s - loss: 0.0016 - 101ms/epoch - 7ms/step
# Epoch 85/180
# 14/14 - 0s - loss: 0.0013 - 115ms/epoch - 8ms/step
# Epoch 86/180
# 14/14 - 0s - loss: 0.0010 - 101ms/epoch - 7ms/step
# Epoch 87/180
# 14/14 - 0s - loss: 7.0368e-04 - 117ms/epoch - 8ms/step
# Epoch 88/180
# 14/14 - 0s - loss: 4.5977e-04 - 100ms/epoch - 7ms/step
# Epoch 89/180
# 14/14 - 0s - loss: 2.8878e-04 - 99ms/epoch - 7ms/step
# Epoch 90/180
# 14/14 - 0s - loss: 2.1827e-04 - 118ms/epoch - 8ms/step
# Epoch 91/180
# 14/14 - 0s - loss: 2.5071e-04 - 100ms/epoch - 7ms/step
# Epoch 92/180
# 14/14 - 0s - loss: 3.5804e-04 - 129ms/epoch - 9ms/step
# Epoch 93/180
# 14/14 - 0s - loss: 5.3225e-04 - 102ms/epoch - 7ms/step
# Epoch 94/180
# 14/14 - 0s - loss: 7.5124e-04 - 98ms/epoch - 7ms/step
# Epoch 95/180
# 14/14 - 0s - loss: 9.4208e-04 - 116ms/epoch - 8ms/step
# Epoch 96/180
# 14/14 - 0s - loss: 0.0011 - 102ms/epoch - 7ms/step
# Epoch 97/180
# 14/14 - 0s - loss: 0.0012 - 117ms/epoch - 8ms/step
# Epoch 98/180
# 14/14 - 0s - loss: 0.0013 - 115ms/epoch - 8ms/step
# Epoch 99/180
# 14/14 - 0s - loss: 0.0012 - 103ms/epoch - 7ms/step
# Epoch 100/180
# 14/14 - 0s - loss: 0.0011 - 114ms/epoch - 8ms/step
# Epoch 101/180
# 14/14 - 0s - loss: 8.4371e-04 - 101ms/epoch - 7ms/step
# Epoch 102/180
# 14/14 - 0s - loss: 6.4469e-04 - 117ms/epoch - 8ms/step
# Epoch 103/180
# 14/14 - 0s - loss: 3.7758e-04 - 99ms/epoch - 7ms/step
# Epoch 104/180
# 14/14 - 0s - loss: 2.4685e-04 - 117ms/epoch - 8ms/step
# Epoch 105/180
# 14/14 - 0s - loss: 1.7621e-04 - 101ms/epoch - 7ms/step
# Epoch 106/180
# 14/14 - 0s - loss: 2.2048e-04 - 117ms/epoch - 8ms/step
# Epoch 107/180
# 14/14 - 0s - loss: 3.9835e-04 - 116ms/epoch - 8ms/step
# Epoch 108/180
# 14/14 - 0s - loss: 6.3916e-04 - 100ms/epoch - 7ms/step
# Epoch 109/180
# 14/14 - 0s - loss: 0.0010 - 117ms/epoch - 8ms/step
# Epoch 110/180
# 14/14 - 0s - loss: 0.0014 - 116ms/epoch - 8ms/step
# Epoch 111/180
# 14/14 - 0s - loss: 0.0020 - 100ms/epoch - 7ms/step
# Epoch 112/180
# 14/14 - 0s - loss: 0.0024 - 116ms/epoch - 8ms/step
# Epoch 113/180
# 14/14 - 0s - loss: 0.0029 - 112ms/epoch - 8ms/step
# Epoch 114/180
# 14/14 - 0s - loss: 0.0029 - 100ms/epoch - 7ms/step
# Epoch 115/180
# 14/14 - 0s - loss: 0.0027 - 100ms/epoch - 7ms/step
# Epoch 116/180
# 14/14 - 0s - loss: 0.0021 - 118ms/epoch - 8ms/step
# Epoch 117/180
# 14/14 - 0s - loss: 0.0012 - 106ms/epoch - 8ms/step
# Epoch 118/180
# 14/14 - 0s - loss: 6.1659e-04 - 107ms/epoch - 8ms/step
# Epoch 119/180
# 14/14 - 0s - loss: 2.9738e-04 - 100ms/epoch - 7ms/step
# Epoch 120/180
# 14/14 - 0s - loss: 2.8043e-04 - 118ms/epoch - 8ms/step
# Epoch 121/180
# 14/14 - 0s - loss: 4.5391e-04 - 101ms/epoch - 7ms/step
# Epoch 122/180
# 14/14 - 0s - loss: 6.7077e-04 - 116ms/epoch - 8ms/step
# Epoch 123/180
# 14/14 - 0s - loss: 9.0203e-04 - 103ms/epoch - 7ms/step
# Epoch 124/180
# 14/14 - 0s - loss: 0.0010 - 113ms/epoch - 8ms/step
# Epoch 125/180
# 14/14 - 0s - loss: 0.0010 - 113ms/epoch - 8ms/step
# Epoch 126/180
# 14/14 - 0s - loss: 8.8343e-04 - 104ms/epoch - 7ms/step
# Epoch 127/180
# 14/14 - 0s - loss: 6.7607e-04 - 115ms/epoch - 8ms/step
# Epoch 128/180
# 14/14 - 0s - loss: 4.3494e-04 - 144ms/epoch - 10ms/step
# Epoch 129/180
# 14/14 - 0s - loss: 2.7015e-04 - 100ms/epoch - 7ms/step
# Epoch 130/180
# 14/14 - 0s - loss: 1.7446e-04 - 116ms/epoch - 8ms/step
# Epoch 131/180
# 14/14 - 0s - loss: 1.9380e-04 - 100ms/epoch - 7ms/step
# Epoch 132/180
# 14/14 - 0s - loss: 3.2807e-04 - 116ms/epoch - 8ms/step
# Epoch 133/180
# 14/14 - 0s - loss: 5.0751e-04 - 100ms/epoch - 7ms/step
# Epoch 134/180
# 14/14 - 0s - loss: 7.5131e-04 - 120ms/epoch - 9ms/step
# Epoch 135/180
# 14/14 - 0s - loss: 9.4551e-04 - 106ms/epoch - 8ms/step
# Epoch 136/180
# 14/14 - 0s - loss: 0.0012 - 107ms/epoch - 8ms/step
# Epoch 137/180
# 14/14 - 0s - loss: 0.0012 - 96ms/epoch - 7ms/step
# Epoch 138/180
# 14/14 - 0s - loss: 0.0012 - 120ms/epoch - 9ms/step
# Epoch 139/180
# 14/14 - 0s - loss: 0.0010 - 96ms/epoch - 7ms/step
# Epoch 140/180
# 14/14 - 0s - loss: 8.9250e-04 - 103ms/epoch - 7ms/step
# Epoch 141/180
# 14/14 - 0s - loss: 6.0694e-04 - 113ms/epoch - 8ms/step
# Epoch 142/180
# 14/14 - 0s - loss: 4.3198e-04 - 104ms/epoch - 7ms/step
# Epoch 143/180
# 14/14 - 0s - loss: 2.4810e-04 - 113ms/epoch - 8ms/step
# Epoch 144/180
# 14/14 - 0s - loss: 2.0493e-04 - 104ms/epoch - 7ms/step
# Epoch 145/180
# 14/14 - 0s - loss: 2.4079e-04 - 119ms/epoch - 8ms/step
# Epoch 146/180
# 14/14 - 0s - loss: 2.5888e-04 - 108ms/epoch - 8ms/step
# Epoch 147/180
# 14/14 - 0s - loss: 5.0709e-04 - 100ms/epoch - 7ms/step
# Epoch 148/180
# 14/14 - 0s - loss: 4.3127e-04 - 116ms/epoch - 8ms/step
# Epoch 149/180
# 14/14 - 0s - loss: 8.5407e-04 - 100ms/epoch - 7ms/step
# Epoch 150/180
# 14/14 - 0s - loss: 4.9516e-04 - 117ms/epoch - 8ms/step
# Epoch 151/180
# 14/14 - 0s - loss: 0.0012 - 117ms/epoch - 8ms/step
# Epoch 152/180
# 14/14 - 0s - loss: 4.2400e-04 - 117ms/epoch - 8ms/step
# Epoch 153/180
# 14/14 - 0s - loss: 0.0016 - 131ms/epoch - 9ms/step
# Epoch 154/180
# 14/14 - 0s - loss: 4.9558e-04 - 100ms/epoch - 7ms/step
# Epoch 155/180
# 14/14 - 0s - loss: 0.0016 - 117ms/epoch - 8ms/step
# Epoch 156/180
# 14/14 - 0s - loss: 6.6629e-04 - 100ms/epoch - 7ms/step
# Epoch 157/180
# 14/14 - 0s - loss: 5.6720e-04 - 120ms/epoch - 9ms/step
# Epoch 158/180
# 14/14 - 0s - loss: 4.7167e-04 - 97ms/epoch - 7ms/step
# Epoch 159/180
# 14/14 - 0s - loss: 2.1848e-04 - 108ms/epoch - 8ms/step
# Epoch 160/180
# 14/14 - 0s - loss: 4.6180e-04 - 112ms/epoch - 8ms/step
# Epoch 161/180
# 14/14 - 0s - loss: 5.1386e-04 - 100ms/epoch - 7ms/step
# Epoch 162/180
# 14/14 - 0s - loss: 7.0498e-04 - 117ms/epoch - 8ms/step
# Epoch 163/180
# 14/14 - 0s - loss: 8.6963e-04 - 131ms/epoch - 9ms/step
# Epoch 164/180
# 14/14 - 0s - loss: 0.0011 - 115ms/epoch - 8ms/step
# Epoch 165/180
# 14/14 - 0s - loss: 0.0012 - 100ms/epoch - 7ms/step
# Epoch 166/180
# 14/14 - 0s - loss: 0.0014 - 101ms/epoch - 7ms/step
# Epoch 167/180
# 14/14 - 0s - loss: 0.0014 - 117ms/epoch - 8ms/step
# Epoch 168/180
# 14/14 - 0s - loss: 0.0014 - 100ms/epoch - 7ms/step
# Epoch 169/180
# 14/14 - 0s - loss: 0.0013 - 117ms/epoch - 8ms/step
# Epoch 170/180
# 14/14 - 0s - loss: 0.0011 - 108ms/epoch - 8ms/step
# Epoch 171/180
# 14/14 - 0s - loss: 8.4433e-04 - 105ms/epoch - 7ms/step
# Epoch 172/180
# 14/14 - 0s - loss: 5.7061e-04 - 100ms/epoch - 7ms/step
# Epoch 173/180
# 14/14 - 0s - loss: 3.5995e-04 - 117ms/epoch - 8ms/step
# Epoch 174/180
# 14/14 - 0s - loss: 2.2891e-04 - 100ms/epoch - 7ms/step
# Epoch 175/180
# 14/14 - 0s - loss: 1.9956e-04 - 117ms/epoch - 8ms/step
# Epoch 176/180
# 14/14 - 0s - loss: 2.5434e-04 - 115ms/epoch - 8ms/step
# Epoch 177/180
# 14/14 - 0s - loss: 3.8426e-04 - 100ms/epoch - 7ms/step
# Epoch 178/180
# 14/14 - 0s - loss: 5.4718e-04 - 117ms/epoch - 8ms/step
# Epoch 179/180
# 14/14 - 0s - loss: 7.0893e-04 - 102ms/epoch - 7ms/step
# Epoch 180/180
# 14/14 - 0s - loss: 8.4697e-04 - 116ms/epoch - 8ms/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 3, 128)            52224
#
#  gru_1 (GRU)                 (None, 64)                37248
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 91585 (357.75 KB)
# Trainable params: 91585 (357.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# [[0.09399547]
#  [0.08763026]
#  [0.07519969]
#  [0.06500455]
#  [0.04678665]
#  [0.044604  ]
#  [0.05238728]
#  [0.05901028]
#  [0.05326749]
#  [0.0470039 ]
#  [0.04063044]
#  [0.03483395]
#  [0.0362251 ]
#  [0.05532137]
#  [0.07916954]
#  [0.09902505]
#  [0.11016187]
#  [0.1235968 ]
#  [0.13827184]
#  [0.15900454]
#  [0.1604599 ]
#  [0.16632529]
#  [0.17347337]
#  [0.18768048]
#  [0.19347075]
#  [0.19646364]
#  [0.19675167]
#  [0.19894496]
#  [0.20192759]
#  [0.20561244]
#  [0.20775194]
#  [0.20773946]
#  [0.20589781]
#  [0.20390138]
#  [0.19899806]
#  [0.18088803]
#  [0.16023846]
#  [0.14751717]
#  [0.13787037]
#  [0.137852  ]
#  [0.14816001]
#  [0.15596919]
#  [0.14513817]
#  [0.12687273]
#  [0.12317249]
#  [0.12443896]
#  [0.1355972 ]
#  [0.14341627]
#  [0.15633605]
#  [0.15888949]
#  [0.1573804 ]
#  [0.16080554]
#  [0.16425635]
#  [0.15495728]
#  [0.14026707]
#  [0.14120635]
#  [0.15637833]
#  [0.16496776]
#  [0.1598093 ]
#  [0.15520841]
#  [0.15521549]
#  [0.15084577]
#  [0.15106523]
#  [0.16711532]
#  [0.19674827]
#  [0.2188581 ]
#  [0.23172797]
#  [0.24310188]
#  [0.25622976]
#  [0.2667563 ]
#  [0.27634126]
#  [0.2787522 ]
#  [0.28371876]
#  [0.28884584]
#  [0.2930575 ]
#  [0.29109007]
#  [0.2908252 ]
#  [0.28925717]
#  [0.29256243]
#  [0.2971099 ]
#  [0.30180383]
#  [0.2880441 ]
#  [0.27239245]
#  [0.25734872]
#  [0.254355  ]
#  [0.24424763]
#  [0.23559184]
#  [0.23026957]
#  [0.23924352]
#  [0.24042161]
#  [0.2305605 ]
#  [0.20780796]
#  [0.65638185]
#  [0.66346806]
#  [0.6698996 ]
#  [0.66986275]
#  [0.67169654]
#  [0.6817918 ]
#  [0.68413335]
#  [0.6843686 ]
#  [0.68968546]
#  [0.68584114]
#  [0.67437404]
#  [0.65895146]
#  [0.64438444]
#  [0.62879074]
#  [0.61603767]
#  [0.60581845]
#  [0.5921281 ]
#  [0.5829154 ]
#  [0.57847863]
#  [0.58545214]
#  [0.59921134]
#  [0.6019454 ]
#  [0.60187596]
#  [0.6023426 ]
#  [0.616751  ]
#  [0.6354441 ]
#  [0.6506665 ]
#  [0.66121256]
#  [0.6656736 ]
#  [0.6646419 ]
#  [0.6673921 ]
#  [0.6682332 ]
#  [0.6693242 ]
#  [0.6700155 ]
#  [0.66448605]
#  [0.6594613 ]
#  [0.65815014]
#  [0.68300396]
#  [0.68961155]
#  [0.6850701 ]
#  [0.6803835 ]
#  [0.6890607 ]
#  [0.708859  ]
#  [0.72774357]
#  [0.74837416]
#  [0.76541436]
#  [0.78430766]
#  [0.79985744]
#  [0.80708   ]
#  [0.8178    ]
#  [0.8255021 ]
#  [0.8362232 ]
#  [0.8411748 ]
#  [0.85254395]
#  [0.8524986 ]
#  [0.860118  ]
#  [0.8631211 ]
#  [0.871707  ]
#  [0.87282217]
#  [0.8762307 ]
#  [0.88232124]
#  [0.88742477]
#  [0.8860208 ]
#  [0.8770187 ]
#  [0.8580254 ]
#  [0.8488827 ]
#  [0.84506816]
#  [0.8451231 ]
#  [0.84866893]
#  [0.84734166]
#  [0.85205495]
#  [0.85736156]
#  [0.8517945 ]
#  [0.8451085 ]
#  [0.84904623]
#  [0.8538388 ]
#  [0.85301936]
#  [0.8554632 ]
#  [0.8582156 ]
#  [0.86148435]
#  [0.8615572 ]
#  [0.8629478 ]]
# 0.044033636902307105

# %%
train_RMSE = plot_traindataset_result(MSFT_X_train, MSFT_y_train , MSFT_index_train)
print("GRU Training set RMSE : ", train_RMSE)
# Out:
# C:\Users\cs20b\AppData\Local\Temp\ipykernel_8364\2882637674.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   predict_result['predicted_mean'] = predict_result.mean(axis=1)
# C:\Users\cs20b\AppData\Local\Temp\ipykernel_8364\2882637674.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   real_price['real_mean'] = real_price.mean(axis=1)
# GRU Training set RMSE :  3.073170344204672

# %%
test_RMSE = plot_traindataset_result(MSFT_X_test, MSFT_y_test, MSFT_index_test)
print("GRU Test set RMSE : ", test_RMSE)
# Out:
# C:\Users\cs20b\AppData\Local\Temp\ipykernel_8364\2882637674.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   predict_result['predicted_mean'] = predict_result.mean(axis=1)
# C:\Users\cs20b\AppData\Local\Temp\ipykernel_8364\2882637674.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   real_price['real_mean'] = real_price.mean(axis=1)
# GRU Test set RMSE :  2.9993499000349706

# %%
model = model_GRU(input_dim, output_dim, feature_size , GOOG_X_train , GOOG_y_train)
print(model.summary())

yhat = model.predict(GOOG_X_test, verbose=0)
print(yhat)

rmse = sqrt(mean_squared_error(GOOG_y_test, yhat))
print(rmse)

# %%
train_RMSE = plot_traindataset_result(GOOG_X_train, GOOG_y_train , GOOG_index_train)
print("GRU Training set RMSE : ", train_RMSE)

# %%
test_RMSE = plot_traindataset_result(GOOG_X_test, GOOG_y_test, GOOG_index_test)
print("GRU Test set RMSE : ", test_RMSE)
